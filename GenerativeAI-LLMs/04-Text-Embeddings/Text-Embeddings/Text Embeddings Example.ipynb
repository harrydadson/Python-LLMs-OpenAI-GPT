# %%
import os, openai
from dotenv import load_dotenv, dotenv_values, find_dotenv

load_dotenv()
config = dotenv_values(".env")
openai.api_key = config["OPENAI_API_KEY"]

# %%
from langchain.embeddings import OpenAIEmbeddings

# %% [markdown]
# <font color='green'>
# Initialize the OpenAIEmbeddings object
# <font>

# %%
embeddings = OpenAIEmbeddings()

# %% [markdown]
# <font color='green'>
# Let's read our input data and get its embedding representation, so that we use it up for our future tasks
# <font>

# %%
import pandas as pd
df = pd.read_csv('Data.csv')
print(df)
# Out:
#          Words
# 0     Elephant
# 1         Lion
# 2        Tiger
# 3          Dog
# 4      Cricket
# 5      Footbal
# 6       Tennis
# 7   Basketball
# 8        Apple
# 9       Orange
# 10      Banana

# %% [markdown]
# <font color='green'>
#     We can use "apply" to apply the get_embedding function to each row in the dataframe because our words are stored in a pandas dataframe. In order to save time and to save the calculated word embeddings in a new csv file called "word_embeddings.csv" rather than calling OpenAI once more to carry out these computations.
#     <font>

# %%
df['embedding'] = df['Words'].apply(lambda x: embeddings.embed_query(x))
df.to_csv('word_embeddings.csv')

# %% [markdown]
# <font color='green'>
#     Let's load the existing file, which contains the embeddings, so that we can save chargers by not hitting the API repeatedly
#     <font>

# %%
new_df = pd.read_csv('word_embeddings.csv')
print(new_df)
# Out:
#     Unnamed: 0       Words                                          embedding
# 0            0    Elephant  [-0.017855134320424067, -0.008739002273680945,...
# 1            1        Lion  [-0.001514446088710819, -0.010011047775235734,...
# 2            2       Tiger  [-0.013353539911357312, -0.0096088277332399, -...
# 3            3         Dog  [-0.0009933243881749651, -0.015114395874422861...
# 4            4     Cricket  [0.003939178751371585, -0.0071971946945413035,...
# 5            5     Footbal  [-0.011457636465443599, -0.008117706169887448,...
# 6            6      Tennis  [-0.022966790023950585, 0.0016101307056064378,...
# 7            7  Basketball  [-0.012779986743709601, -0.013293189227440112,...
# 8            8       Apple  [0.014476476473958088, -0.00390673109200909, -...
# 9            9      Orange  [0.02067122263312988, -0.029222075283705507, 9...
# 10          10      Banana  [-0.012999765903696864, -0.01998321619391984, ...

# %% [markdown]
# <font color='green'>
# Let's get the embeddings for our text
# <font>

# %%
our_Text = "Mango"

# %%
text_embedding = embeddings.embed_query(our_Text)

# %%
print (f"Our embedding is {text_embedding}")
# Out:
# Our embedding is [-0.0033961603494176745, -0.019859389833244062, 0.010447266248561465, -0.016127768497880515, 0.0063833755696348915, 0.008479218716502984, -0.02520123433196036, -0.014223618074734925, 0.0011437680517106163, -0.03299674681191176, -0.0011805091920153584, 0.0036868945698438384, 0.0019632554118714615, 0.016741185958850564, -0.021674084862705133, 0.004725231670073206, 0.03266448072797766, -0.008146950769923783, 0.009335446867722615, -0.015769941335207135, -0.015872176336938743, 0.0028562251690571095, 0.0014672499013421258, -0.012396144368549316, 0.004511174166607023, 0.009578258489294746, 0.02444724304511744, -0.013622979290489412, 0.011603814257565128, 0.003110218249178531, 0.04789768038785218, -0.014939271468759131, -0.004351429997340966, -0.009916916239897492, -0.01754629567788184, 0.004680503041908396, -0.010351420119530852, -0.0063290627010960405, -0.006297113680978319, -0.018223611179087332, 0.01444086954889033, -0.008402541068220451, -0.015782720943254225, -0.018019137450333914, -0.015527129713635002, 0.02357823342320562, -0.002808301871711165, -0.010127777910029353, -0.041942420290810925, 0.004188491391724413, 0.0043801841154469156, 0.02198079359319016, -0.014747578279375353, 0.0016158119135669799, 0.0013522341274102418, -0.007124588179753275, -0.006977623618534308, 0.021891336336860537, -0.0035559045186837313, 0.006012769264575699, 0.004031942124470129, 0.016204444283517944, -0.023488778029521103, 0.006824269253291795, -0.001134982071178243, -0.0015191667097874666, -0.0016357799347252368, -0.011706050190619285, 0.023271524692720594, 0.01813415392275771, 0.02212136741906303, 0.009814679375520784, 0.004450471494044627, 0.014300294791694906, 0.016600610270332588, 0.0012044707242730118, -0.03166767875088516, -0.008466439108455895, -0.004945678511901658, 0.001524757788308068, 0.03199994483481926, -0.014760357887422441, -0.00412459335148897, 0.02144405191785754, 0.024242769316364023, 0.005932897179942671, -0.0014161317019844091, 0.002011178709217406, -0.0007627782569055055, -0.024012738234161533, -0.00017142542788319446, 0.0027571836723534484, 0.013968026845115703, 0.005549511266836391, -0.024843407169286985, -0.014479208373031594, -0.0012148541558112712, 0.020830634456887487, 0.0038562234451452113, -0.036779488442108765, -0.013444066640475275, 0.011214038074774026, -0.026734777984385484, -0.0017236391579723766, -0.020089422778091656, 0.007897750275650657, 0.0109648375805009, -0.004057500874903031, 0.03228109621185521, -0.02506066050608749, -0.0027204425320487063, 0.020434470332717947, 0.01222362152255872, -0.05216604339854834, -0.016741185958850564, -0.02221082467539265, 0.0018162908506524937, 0.01459422391413284, 0.0012547901981277854, -0.025162895507819097, 0.0014560677443009233, 0.023207628515130255, 0.028217203204622253, -0.013610200613764875, 0.020421690724670857, -0.016753965566897653, 0.0018690063846007775, -0.028472793502918925, -0.011916912792073697, -0.011680490974525108, 0.03979545731477065, 0.009028738137237589, -0.0004680503216531374, 0.010121388106005809, 0.008421710480291085, 0.01745683842155222, -0.03744402433526717, 0.012632566186097902, -0.004984016870381648, -0.01952712374930996, 0.005642162959516507, 0.01900316168202443, -0.01704789468933559, -0.0173673830278677, -0.013929688020974437, 0.021712421824201297, 0.04099673302061657, 0.024408904220976177, 0.012153333678299733, -0.009776340551379518, 0.022862580960503965, -0.02497120324975787, 0.02196801398514307, 0.0034153295286576697, 0.019897728657385327, 0.00962937599016055, -0.0014536715677920943, 0.008031935228822536, -0.005760373402629526, 0.0049904066744051925, 0.012396144368549316, -0.017916902448602307, -0.012261959415377435, -0.012811479767434592, 0.004504784362583478, 0.021175682011513777, 0.011814675927696987, -0.009335446867722615, 0.004038331928493673, -0.011169309446609217, -0.0010686882036799275, 0.028549471151201454, -0.025993566305589653, 0.03453029232698199, 0.01683064135253508, 0.010568671593686256, 0.005252387242386683, 0.00987 ...

# %% [markdown]
# <font color='green'>
#     We can determine how similar a word is to other words in our dataframe after we have a vector representing that word.
#     <br>
# By computing the cosine similarity of the word vector for our search term to each word embedding in our dataframe.
#     <font>

# %%
from openai.embeddings_utils import cosine_similarity

df["similarity score"] = df['embedding'].apply(lambda x: cosine_similarity(x, text_embedding))

df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/harryd/Desktop/Self-Study/GenerativeAI-LLMs/04-Text-Embeddings/Text Embeddings Example.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/Users/harryd/Desktop/Self-Study/GenerativeAI-LLMs/04-Text-Embeddings/Text%20Embeddings%20Example.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> from openai.embeddings_utils import cosine_similarity
#       <a href='vscode-notebook-cell:/Users/harryd/Desktop/Self-Study/GenerativeAI-LLMs/04-Text-Embeddings/Text%20Embeddings%20Example.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> df["similarity score"] = df['embedding'].apply(lambda x: cosine_similarity(x, text_embedding))
#       <a href='vscode-notebook-cell:/Users/harryd/Desktop/Self-Study/GenerativeAI-LLMs/04-Text-Embeddings/Text%20Embeddings%20Example.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a> df
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/embeddings_utils.py:7
#       5 import plotly.express as px
#       6 from scipy import spatial
# ----> 7 from sklearn.decomposition import PCA
#       8 from sklearn.manifold import TSNE
#       9 from sklearn.metrics import average_precision_score, precision_recall_curve
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# <font color='green'>
#     Sorting by similarity values in dataframe reveals Banana, Orange, and Apple are closest to searched term, such as Mango.
#     <font>

# %%
df.sort_values("similarity score", ascending=False).head(10)
# Out:
#      Words                                          embedding  \
# 6   Banana  [-0.013021613471210003, -0.019990751519799232,...
# 5   Orange  [0.020670153200626373, -0.029327111318707466, ...
# 4    Apple  [0.01444941945374012, -0.0039136698469519615, ...
# 3     Bike  [0.0054834443144500256, -0.013623781502246857,...
# 1  College  [0.008637277409434319, -0.009738443419337273, ...
# 0   School  [0.00558300968259573, 0.009224693290889263, -0...
# 2      Car  [-0.004948626272380352, -0.012337295338511467,...
#
#    similarity score
# 6          0.898687
# 5          0.843855
# 4          0.813925
# 3          0.797835
# 1          0.782224
# 0          0.781657
# 2          0.780015
