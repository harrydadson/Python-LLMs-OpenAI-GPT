# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient

import os
import openai
from dotenv import load_dotenv, dotenv_values

load_dotenv()
config = dotenv_values(".env")

API_KEY = config["API_KEY"]
ENDPOINT = config["ENDPOINT"]

# %%
def client():
    try:
        ta_credential = AzureKeyCredential(API_KEY)
        text_analytics_client = TextAnalyticsClient(
            endpoint=ENDPOINT, 
            credential=ta_credential)
        return text_analytics_client
    except Exception as e:
        print("Error: {e}")
        return None

# %%
Documents = [
	"""
	I have to say that I love this thing. I read a majority of the reviews here on Amazon before I placed my order, and I can say that 95% of the complaints in other reviews are unwarranted.

    Complaints others have had:
    - Short/Fixed USB Cable :: I don't understand this one. Every single wired keyboard and mouse I've ever owned had a fixed cable of the same length. If it doesn't work for you, neither do your mouse and keyboard.
    - LCD "ripples" when you press buttons :: Try not pressing buttons like a 200lb gorilla. Mine doesn't ripple unl
    Complaints others have had:
    - Short/Fixed USB Cable :: I don't understand this one. Every single wired keyboard and mouse I've ever owned had a fixed cable of the same length. If it doesn't work for you, neither do your mouse and keyboard.
    - LCD "ripples" when you press buttons :: Try not pressing buttons like a 200lb gorilla. Mine doesn't ripple unless I really try to make it do so.
    - There's no built-in functions for MYSOFTWARE :: ... This one annoys me greatly. It's built for streaming software. It literally has STREAM in the name. That said, you can set up custom key binds with custom images for the keys all you want. They work great. I have mine doing a dozen functions that technically aren't supported for OBS, Photoshop, and several other programs.
    - It feels cheap/cheaply made :: What planet these people live on is beyond me... This thing is amazingly well built.
    - There's a long delay when I press buttons! :: Try not streaming on a potato. Mine works beautifully. Any delay is on the users end. (too much BS running in the background/slow computer)
    - It's overpriced! :: If you think this is overpriced, you haven't looked at similar products. Programmable keypads with similar functions (with NO LCD) are just as/more expensive.
    - There's only one LCD, it's not individual displays for each key! :: Who cares? It functions and looks great in the process.

    My Complaints:
    - Fairly minimal native OBS options. This is easily overcome with custom key binds, it would have just been nice to have things like mute mic built-in.
    - Always on display. It really needs to pick up on when the PC display shuts off due to inactivity and do the same. (or shut off when the computer is locked, either way)

    The TLDR: It's great. It works beautifully for streaming, and just as well as a general productivity helper. I don't regret ordering mine and I doubt anybody else will either. 
    """
]

# %%
client = client()
response = client.analyze_sentiment(
    documents=Documents, 
    language='en-US', 
    show_opinion_mining=True)

positive_reviews = [doc for doc in response if doc.sentiment == "positive"]
mixed_reviews = [doc for doc in response if doc.sentiment == "mixed"]
negative_reviews = [doc for doc in response if doc.sentiment == "negative"]

# %%
# Result 
# Predicted sentiment for document

for doc in response:
    print('Sentiment Analysis Outcome: {}'.format(doc.sentiment))   
    
    # Document level sentiment confidence scores between 0 and 1 for each sentiment label.
    print('Overall scores: positive={0:.2f}; neutral={1:.2f}; negative={2:.2f} \n'.format(
        doc.confidence_scores.positive,
        doc.confidence_scores.neutral,
        doc.confidence_scores.negative,
    ))
    print('-'*75)
# Out:
# Sentiment Analysis Outcome: mixed
# Overall scores: positive=0.45; neutral=0.13; negative=0.42
#
# ---------------------------------------------------------------------------

# %%
# Break down the analysis by each sentence, then reference the sentence attribue to see the sentence text and score.
sentences = doc.sentences
for indx, sentence in enumerate(sentences):
    print('Sentence #{0}'.format(indx+1))
    print('Sentence text: {0}'.format(sentence.text))
    print('Sentence scores: positive={0:.2f}; neutral={1:.2f}; negative={2:.2f}'.format(
        sentence.confidence_scores.positive,
        sentence.confidence_scores.neutral,
        sentence.confidence_scores.negative,
    ))
    
    # opinion analysit
    for mined_opinion in sentence.mined_opinions:
        target = mined_opinion.target
        print("...'{}' target '{}'".format(
            target.sentiment,
            target.text
        ))
        print("......Target score: \n......Positive={0:.2f}\n......Negative={1:.2f}\n".format(
            target.confidence_scores.positive,
            target.confidence_scores.negative,
        ))
        for assesment in mined_opinion.assessments:
            print("......'{}' assessment '{}'".format(
                assesment.sentiment,
                assesment.text
            ))
            print(".........Assessment score: \n.........Positive={0:.2f}\n.........Negative={1:.2f}\n".format(
                assesment.confidence_scores.positive,
                assesment.confidence_scores.negative,
            ))
    print()
# Out:
# Sentence #1
# Sentence text:  	I have to say that I love this thing.
# Sentence scores: positive=0.93; neutral=0.05; negative=0.02
#
# Sentence #2
# Sentence text: I read a majority of the reviews here on Amazon before I placed my order, and I can say that 95% of the complaints in other reviews are unwarranted.
#
# Sentence scores: positive=0.02; neutral=0.31; negative=0.68
#
# Sentence #3
# Sentence text:     Complaints others have had:     - Short/Fixed USB Cable :: I don't understand this one.
# Sentence scores: positive=0.01; neutral=0.28; negative=0.71
#
# Sentence #4
# Sentence text: Every single wired keyboard and mouse I've ever owned had a fixed cable of the same length.
# Sentence scores: positive=0.01; neutral=0.99; negative=0.01
#
# Sentence #5
# Sentence text: If it doesn't work for you, neither do your mouse and keyboard.
# Sentence scores: positive=0.02; neutral=0.53; negative=0.45
#
# Sentence #6
# Sentence text: - LCD "ripples" when you press buttons :: Try not pressing buttons like a 200lb gorilla.
# Sentence scores: positive=0.02; neutral=0.96; negative=0.03
#
# Sentence #7
# Sentence text: Mine doesn't ripple unl     Complaints others have had:     - Short/Fixed USB Cable :: I don't understand this one.
# Sentence scores: positive=0.01; neutral=0.22; negative=0.77
#
# Sentence #8
# Sentence text: Every single wired keyboard and mouse I've ever owned had a fixed cable of the same length.
# Sentence scores: positive=0.01; neutral=0.99; negative=0.01
#
# Sentence #9
# Sentence text: If it doesn't work for you, neither do your mouse and keyboard.
# Sentence scores: positive=0.01; neutral=0.64; negative=0.35
#
# Sentence #10
# Sentence text: - LCD "ripples" when you press buttons :: Try not pressing buttons like a 200lb gorilla.
# Sentence scores: positive=0.03; neutral=0.91; negative=0.06
#
# Sentence #11
# Sentence text: Mine doesn't ripple unless I really try to make it do so.
# Sentence scores: positive=0.02; neutral=0.83; negative=0.16
#
# Sentence #12
# Sentence text: - There's no built-in functions for MYSOFTWARE :: ...
# Sentence scores: positive=0.01; neutral=0.86; negative=0.13
#
# Sentence #13
# Sentence text: This one annoys me greatly.
# Sentence scores: positive=0.00; neutral=0.01; negative=0.99
#
# Sentence #14
# Sentence text: It's built for streaming software.
# Sentence scores: positive=0.01; neutral=0.98; negative=0.01
#
# Sentence #15
# Sentence text: It literally has STREAM in the name.
# Sentence scores: positive=0.01; neutral=0.99; negative=0.00
#
# Sentence #16
# Sentence text: That said, you can set up custom key binds with custom images for the keys all you want.
# Sentence scores: positive=0.02; neutral=0.97; negative=0.00
#
# Sentence #17
# Sentence text: They work great.
# Sentence scores: positive=0.99; neutral=0.01; negative=0.00
#
# Sentence #18
# Sentence text: I have mine doing a dozen functions that technically aren't supported for OBS, Photoshop, and several other programs.
# Sentence scores: positive=0.01; neutral=0.86; negative=0.13
# ...'negative' target 'functions'
# ......Target score:
# ......Positive=0.02
# ......Negative=0.98
#
# ......'negative' assessment 'supported'
# .........Assessment score:
# .........Positive=0.02
# .........Negative=0.98
#
#
# Sentence #19
# Sentence text: - It feels cheap/cheaply made :: What planet these people live on is beyond me...
# Sentence scores: positive=0.06; neutral=0.52; negative=0.42
#
# Sentence #20
# Sentence text: This thing is amazingly well built.
# Sentence scores: positive=0.97; neutral=0.02; negative=0.01
# ...'positive' target 'thing'
# ......Target score:
# ......Positive=1.00
# ......Negative=0.00
#
# ......'positive' assessment 'well built'
# .........Assessment score:
# .........Positive=1.00
# .........Negative=0.00
#
#
# Sentence #21
# Sentence text: - There's a long delay when I press buttons!
# Sentence scores: positive=0.04; neutral=0.27; negative=0.69
#
# Sentence #22
# Sentence text: :: Try not streaming on a potato.
# Sentence scores: positive=0.02; neutral=0.92; negative=0.06
#
# Sentence #23
# Sentence text: Mine works beautifully.
# Sentence scores: positive=0.99; neutral=0.01; negative=0.00
#
# Sentence #24
# Sentence text: Any delay is on the users end.
# Sentence scores: positive=0.01; neutral=0.88; negative=0.11
#
# Sentence #25
# Sentence text: (too much BS running in the background/slow computer)     - It's overpriced!
# Sentence scores: positive=0.00; neutral=0.01; negative=0.99
#
# Sentence #26
# Sentence text: :: If you think this is overpriced, you haven't looked at similar products.
# Sentence scores: positive=0.02; neutral=0.47; negative=0.51
#
# Sentence #27
# Sentence text: Programmable keypads with similar functions (with NO LCD) are just as/more expensive.
# Sentence scores: positive=0.00; neutral=0.05; negative=0.94
# ...'negative' target 'keypads'
# ......Target score:
# ......Positive=0.08
# ......Negative=0.92
#
# ......'negative' assessment 'expensive'
# .........Assessment score:
# .........Positive=0.08
# .........Negative=0.92
#
#
# Sentence #28
# Sentence text: - There's only one LCD, it's not individual displays for each key!
# Sentence scores: positive=0.02; neutral=0.77; negative=0.21
#
# Sentence #29
# Sentence text: :: Who cares?
# Sentence scores: positive=0.08; neutral=0.81; negative=0.10
#
# Sentence #30
# Sentence text: It functions and looks great in the process.
#
# Sentence scores: positive=0.98; neutral=0.01; negative=0.00
#
# Sentence #31
# Sentence text:     My Complaints:     - Fairly minimal native OBS options.
# Sentence scores: positive=0.02; neutral=0.25; negative=0.72
#
# Sentence #32
# Sentence text: This is easily overcome with custom key binds, it would have just been nice to have things like mute mic built-in.
# Sentence scores: positive=0.93; neutral=0.06; negative=0.01
#
# Sentence #33
# Sentence text: - Always on display.
# Sentence scores: positive=0.05; neutral=0.94; negative=0.01
#
# Sentence #34
# Sentence text: It really needs to pick up on when the PC display shuts off due to inactivity and do the same.
# Sentence scores: positive=0.01; neutral=0.57; negative=0.41
#
# Sentence #35
# Sentence text: (or shut off when the computer is locked, either way)
#
# Sentence scores: positive=0.00; neutral=0.99; negative=0.01
#
# Sentence #36
# Sentence text:     The TLDR: It's great.
# Sentence scores: positive=0.91; neutral=0.08; negative=0.02
#
# Sentence #37
# Sentence text: It works beautifully for streaming, and just as well as a general productivity helper.
# Sentence scores: positive=0.99; neutral=0.01; negative=0.00
#
# Sentence #38
# Sentence text: I don't regret ordering mine and I doubt anybody else will either.
# Sentence scores: positive=0.33; neutral=0.22; negative=0.45
