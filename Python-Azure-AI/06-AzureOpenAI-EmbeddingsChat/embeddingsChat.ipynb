# %%
import openai
import os
from openai import AzureOpenAI
from dotenv import load_dotenv, dotenv_values

load_dotenv()
config = dotenv_values(".env")

# %%
from langchain.chat_models import AzureChatOpenAI
from langchain.llms import AzureOpenAI

os.environ["OPENAI_API_TYPE"] = "azure"
os.environ["OPENAI_API_VERSION"] = "2023-05-15"
os.environ["OPENAI_API_BASE"] = config["OPENAI_API_BASE"]
os.environ["OPENAI_API_KEY"] = config["OPENAI_API_KEY"]

AzureOpenAI(
    # api_key = config["OPENAI_API_KEY"],
    # base_url = config["OPENAI_API_BASE"],
    # api_version="2023-08-01-preview"
    #deployment_name = "gpt-35-turbo",
    model_name = "gpt-35-turbo",
    temperature = 0
)

# AzureOpenAI(
#                 deployment_name="gpt-35=turbo",
#                 openai_api_type="azure",
#                 openai_api_version="2023-07-01-Preview",
#                 azure_endpoint="https://hd-openai.openai.azure.com/openai/deployments/gpt-35-turbo/chat/completions?api-version=2023-07-01-preview"
#             )

from llama_index import GPTVectorStoreIndex, SimpleDirectoryReader

documents = SimpleDirectoryReader('news').load_data()
index = GPTVectorStoreIndex.from_documents(documents)

query_engine = index.as_query_engine()

r = query_engine.query("Large language models (LLM) are renowned for what ability?")
print(r)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /Users/harryd/Desktop/Self-Study/Python-LLMs-OpenAI-GPT/Python-Azure-AI/06-AzureOpenAI-EmbeddingsChat/embeddingsChat.ipynb Cell 2 line 2
#      <a href='vscode-notebook-cell:/Users/harryd/Desktop/Self-Study/Python-LLMs-OpenAI-GPT/Python-Azure-AI/06-AzureOpenAI-EmbeddingsChat/embeddingsChat.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a> from llama_index import GPTVectorStoreIndex, SimpleDirectoryReader
#      <a href='vscode-notebook-cell:/Users/harryd/Desktop/Self-Study/Python-LLMs-OpenAI-GPT/Python-Azure-AI/06-AzureOpenAI-EmbeddingsChat/embeddingsChat.ipynb#W3sZmlsZQ%3D%3D?line=26'>27</a> documents = SimpleDirectoryReader('news').load_data()
# ...
